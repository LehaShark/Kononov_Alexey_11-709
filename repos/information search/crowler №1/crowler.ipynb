# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

count = 0
num = 39
while True:
    count = count + 1
    num = num + 1
    
    url = f"https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-{count}-igor-smirnov-roman-tajn-doktor-zhivago.html#text"
    print(str(url))
    html = urlopen(url).read()
    soup = BeautifulSoup(html, features="html.parser")

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

# get text
    text = soup.get_text()

# break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)
    
    #print(text)
    
    page = open(f"page{num}.txt", 'w', encoding='utf-8')
    index = open("index.txt", 'a')

    index.write(str(num) + '. ' + url + '\n') 
    page.write(text)
    page.close()
    index.close()
# Out:
# https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-1-igor-smirnov-roman-tajn-doktor-zhivago.html#text
# https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-2-igor-smirnov-roman-tajn-doktor-zhivago.html#text
# https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-3-igor-smirnov-roman-tajn-doktor-zhivago.html#text
# https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-4-igor-smirnov-roman-tajn-doktor-zhivago.html#text
# https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-5-igor-smirnov-roman-tajn-doktor-zhivago.html#text
# https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-6-igor-smirnov-roman-tajn-doktor-zhivago.html#text
# https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-7-igor-smirnov-roman-tajn-doktor-zhivago.html#text
# https://libcat.ru/knigi/nauka-i-obrazovanie/kulturologiya/185779-8-igor-smirnov-roman-tajn-doktor-zhivago.html#text
# ...
