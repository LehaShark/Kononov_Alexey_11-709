# %%
from PIL import Image, ImageDraw

_SIZE_WIDTH = 106
_SIZE_HEIGHT = 17

def welcome() -> None:
    print("Расшифровка числа по формуле Таппера")

def get_image() -> None:

    def get_k() -> int:
        return int(input("Введите k:"))

    def from_k_to_bin(k: int) -> list:
        k //= 17
        binary = bin(k)[2:]

        if len(binary) < 1802:
            new_binary = ""
            for i in range(1802-len(binary)):
                new_binary += "0"
            binary = new_binary + binary

        lists = [[] for x in range(17)]
        for x in range(1802):
            lists[x%17].append(binary[x])

        lists.reverse()
        return lists

    k = get_k()
    lists = from_k_to_bin(k)

    #График
    image = Image.new("1", (106,17), (0))
    draw = image.load()
    for y in range(17):
        for x in range(106):
            image.putpixel(xy = (105-x,16-y), value = (int(lists[y][x]),))
    image.save("image.png")


def generate_image() -> None:

    def attention() -> None:
        print("106х17 пикселей")

    def get_image() -> Image:
        name = input("файл:")
        try:
            im = Image.open(name)
        except Exception:
            print("Fuck u")
            exit(0)

        return im

    attention()
    image = get_image()
    width, height = image.size

    flag_okay = False
    if width == _SIZE_WIDTH and height == _SIZE_HEIGHT:
        flag_okay = True

    if not flag_okay:
        print("fuck u")
        print(width, height)
        exit(0)

    print("ok")
    image = image.convert('1')
    image.save('result.png')

    byteset = ""
    for x in range(105,-1,-1):
        for y in range(0,17):
            byte = str(image.getpixel((x,y)))
            if byte == "255":
                byteset += '1'
            else:
                byteset += '0'

    k = int(byteset,2)*17

    print("Ваше число:")
    print(k)

def main():
    welcome()
    print("Из k получить изображение (0) или из изображения получить k (1) ?")
    choice = int(input())
    if choice > 1:
        main()
    else:
        if choice == 0:
            get_image()
        else:
            generate_image()

if __name__ == '__main__':
    main()
# Out:
# Расшифровка числа по формуле Таппера
# Из k получить изображение (0) или из изображения получить k (1) ?
# 0
# Введите k:960 939 379 918 958 884 971 672 962 127 852 754 715 004 339 660 129 306 651 505 519 271 702 802 395 266 424 689 642 842 174 350 718 121 267 153 782 770 623 355 993 237 280 874 144 307 891 325 963 941 337 723 487 857 735 749 823 926 629 715 517 173 716 995 165 232 890 538 221 612 403 238 855 866 184 013 235 585 136 048 828 693 337 902 491 454 229 288 667 081 096 184 496 091 705 183 454 067 827 731 551 705 405 381 627 380 967 602 565 625 016 981 482 083 418 783 163 849 115 590 225 610 003 652 351 370 343 874 461 848 378 737 238 198 224 849 863 465 033 159 410 054 974 700 593 138 339 226 497 249 461 751 545 728 366 702 369 745 461 014 655 997 933 798 537 483 143 786 841 806 593 422 227 898 388 722 980 000 748 404 719
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-f5d1797e9009> in <module>
#     106
#     107 if __name__ == '__main__':
# --> 108     main()
#
# <ipython-input-2-f5d1797e9009> in main()
#     101     else:
#     102         if choice == 0:
# --> 103             get_image()
#     104         else:
#     105             generate_image()
#
# <ipython-input-2-f5d1797e9009> in get_image()
#      35
#      36
# ---> 37     k = get_k()
#      38     lists = from_k_to_bin(k)
#      39
#
# <ipython-input-2-f5d1797e9009> in get_k()
#      14
#      15     def get_k() -> int:
# ---> 16         return int(input("Введите k:"))
#      17
#      18     def from_k_to_bin(k: int) -> list:
#
# ValueError: invalid literal for int() with base 10: '960 939 379 918 958 884 971 672 962 127 852 754 715 004 339 660 129 306 651 505 519 271 702 802 395 266 424 689 642 842 174 350 718 121 267 153 782 770 623 355 993 237 280 874 144 307 891 325 963 941
