# %% [markdown]
# Подключаем библиотеки.
#
#
# Библиотека string понадобится для обработки строк, а именно для очистки строк от различных знаков препинания.
#
#
# Библиотека pymorphy2 понадобится для приведения слова к начальной форме.
#
#
# Библиотека nltk понадобится для загрузки стоп-слов (например, "это", "я", "ты")

# %%
import numpy as np
import string
import pymorphy2
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Alexe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Предварительно подготавливаем два текстовых файла. В первый из них записываем спам-сообщения, во второй - примеры информативных сообщений.
# Построчно читаем оба файла и создаем два соответствующих массива, элементам которых соответствуют прочитанные строки из файла.

# %%
with open('spam.txt') as file:
    spam = [row.strip() for row in file]
    
with open('inf.txt') as file:
    inf = [row.strip() for row in file]

# %% [markdown]
# Создаем метод по предобработке предложений:
#
# 1)переводим буквы из верхнего регистра в нижний
#
#
# 2)убираем из предложений знаки пунктуации
#
#
# 3)убираем из предложения стоп-слова
#
# Затем, с помощью библиотеки pymorphy2 приводим все слова к начальной форме.

# %%
def preprocess(name):
    #print(name)
    morph = pymorphy2.MorphAnalyzer(lang='ru')
    result = []

    for line in name:
        
        line = line.lower()
        line = ''.join([t for t in line if t not in string.punctuation])
        line = [t for t in line.split() if t not in stopwords.words('russian')]
        temp = []
        for word in line:
            temp.append(morph.parse(word)[0].normal_form)
        result += [temp]

    return result

# %% [markdown]
# Каждому из предложений выборки ставим в соответствие метку 0 или 1 (0 = спам, 1 = не спам)

# %%
dataset = []

for item in preprocess(spam):
    dataset += [[item, 0]]
for item in preprocess(inf):
    dataset += [[item, 1]]
    
print(dataset)
# Out:
# [[['привет', 'давать', 'заходить', 'мы', 'новый', 'коллекция', 'платье'], 0], [['сегодня', 'зайти', 'наш', 'сайт', 'получите…'], 0], [['сегодня', 'распродажа'], 0], [['течение', 'неделя', 'смочь', 'купить', 'платье', 'превлекательный', 'цена'], 0], [['сегодня', 'самый', 'день', 'смочь', 'зайти', 'наш', 'магазин', 'воспользоваться', 'большой', 'скидка', 'который', 'давать', 'именно'], 0], [['пожалуйста', 'срочно', 'открыть', 'прочитать', 'это', 'письмо', 'конец'], 0], [['сегодня', 'скидка', '50'], 0], [['хотеть', 'получить', 'наличный', 'деньга', 'бесплатно', 'рассказать', 'получить', 'дополнительный', 'доход', 'благодаря', 'бизнес', 'дом'], 0], [['проверить', 'свой', 'vip', 'статус', 'помощь', 'специальный', 'сервис'], 0], [['зарегистрироваться', 'ссылка', 'ниже', 'добавить', 'друг'], 0], [['купить', 'электронный', 'книга', '«целевой', 'маркетинг»', 'сегодня', '23'], 0], [['заработать', '50000', 'свой', 'следующий', 'сделка'], 0], [['провести', 'опрос', 'среди', 'наш', 'подписчик', 'шаблон', 'письмо', 'нравиться', 'ответить'], 0], [['загрузить', 'наш', 'новый', 'шаблон', 'электронный', 'письмо'], 0], [['успешный', 'маркетолог', 'прочитать', 'книга'], 0], [['87', 'успешный', 'маркетолог', 'прочитать', 'книга'], 0], [['нынешний', 'климат', 'электронный', 'коммерции…'], 0], [['онлайн', 'продажах…'], 0], [['искать', 'информация', 'предоставлять'], 0], [['мы', 'нужный', 'ваш', 'помощь', 'пожалуйста', 'прочитать'], 0], [['этот', 'книга', 'исчезнуть', 'свободный', 'доступ', 'четверг'], 0], [['сегодня', 'заставить', 'свой', 'маркетинг', 'работать', 'автопилот'], 0], [['эксклюзивный', 'интервью', 'марк', 'кьюбан', 'доступно', 'сегодня'], 0], [['этот', 'инвестиционный', 'хитрость', 'принести', 'непредвиденный', 'богатство', 'спешить', 'увидеть'], 0], [['десять', 'необычный', 'тактика', 'привлечение', 'потенциальный', 'клиент'], 0], [['ваш', 'отдел', 'продажа', 'совершать', 'фатальный', 'ошибка'], 0], [['недооценить', 'стратегия', 'социальный', 'сеть', 'который', 'забывать'], 0], [['один', 'это', 'слово', 'повысить', 'ваш', 'конверсия', '357'], 0], [['стать', 'первый', 'испробовать', 'наш', 'новый', 'продукт'], 0], [['выиграть', 'билет', 'наш', 'следующий', 'конференция'], 0], [['хотеть', 'зарабатывать', '10000', 'месяц', 'этот', 'схема', 'изменить', 'ваш', 'жизнь'], 0], [['ошибка', 'маркетинг', 'ободрать', 'липка'], 0], [['максимальный', 'выгода', 'товар', 'против', 'covid19', 'снизить', 'цена'], 0], [['важно', 'прочитать948725885539919561647675'], 0], [['щедрый', 'декабрь', 'дарить', 'скидка', 'весь'], 0], [['читать', 'бесплатный', 'учебник', 'решение', 'бизнесзадача'], 0], [['идейный', 'соображение', 'высокий', 'порядок', 'также', 'дальнейший', 'развитие', 'различный', 'форма', 'деятельность', 'позволять', 'оценить', 'значение', 'новый', 'предложение'], 1], [['товарищ', 'консультация', 'широкий', 'актив', 'позволять', 'выполнять', 'важный', 'задание', 'разработка', 'система', 'массовый', 'участие'], 1], [['сторона', 'рамка', 'место', 'обучение', 'кадр', 'способствовать', 'подготовка', 'реализация', 'модель', 'развитие'], 1], [['сторона', 'постоянный', 'информационнопропагандистский', 'обеспечение', 'наш', 'деятельность', 'обеспечивать', 'широкий', 'круг', 'специалист', 'участие', 'формирование', 'позиция', 'занимать', 'участник', 'отношение', 'поставить', 'задача'], 1], [['равный', 'образ', 'рамка', 'место', 'обучение', 'кадр', 'влечь', 'себя', 'процесс', 'внедрение', 'модернизация', 'система', 'обучение', 'кадр', 'соответствовать', 'насущный', 'потребность'], 1], [['сторона', 'укрепление', 'развитие', 'структура', 'обеспечивать', 'участие', 'формирование', 'система', 'массовый', 'участие'], 1], [['повседневный', 'практика', 'показывать', 'укрепление', 'развитие', 'структура', 'обеспечивать', 'широкий', 'круг', 'специалист', 'участие', 'формирование', 'дальнейший', 'направление', 'развитие'], 1], [['сторона', 'укрепление', 'развитие', 'структура', 'обеспечивать', 'участие', 'формирование', 'система', 'массовый', 'участие'], 1], [['сто ...

# %%
def fit(dataset, alpha):
    classes, freq, total = {}, {}, set()
    for features, label in dataset:
        if label not in classes:
            classes[label] = 0
        classes[label] += 1
        for feature in features:
            if (feature, label) not in freq:
                freq[(feature, label)] = 0
            freq[(feature, label)] += 1
        total.add(tuple(features))
            
    for feature, label in freq:
        freq[(feature, label)] = (alpha + freq[(feature, label)]) / \
        (alpha*len(total) + classes[label])
    for cl in classes:
        classes[cl] /= len(dataset)        
    return classes, freq

def classify(classifier, features):
    classes, freq = classifier
    return max(classes.keys(),\
              key = lambda cl: np.log10(classes[cl]) +\
               sum(np.log10(freq.get((feature, cl), 10**(-7)))\
                   for feature in features))

# %% [markdown]
# Сохраняем созданный словарь в виде файла pkl:

# %%
classifier = fit(dataset, .5)

# %%
import joblib
joblib.dump(classifier, 'dictionary.pkl')
# Out:
# ['dictionary.pkl']

# %%
import joblib
classr = joblib.load('dictionary.pkl')
print(classr)
# Out:
# ({0: 0.5, 1: 0.5}, {('привет', 0): 0.022388059701492536, ('давать', 0): 0.03731343283582089, ('заходить', 0): 0.022388059701492536, ('мы', 0): 0.03731343283582089, ('новый', 0): 0.05223880597014925, ('коллекция', 0): 0.022388059701492536, ('платье', 0): 0.03731343283582089, ('сегодня', 0): 0.11194029850746269, ('зайти', 0): 0.03731343283582089, ('наш', 0): 0.09701492537313433, ('сайт', 0): 0.022388059701492536, ('получите…', 0): 0.022388059701492536, ('распродажа', 0): 0.022388059701492536, ('течение', 0): 0.022388059701492536, ('неделя', 0): 0.022388059701492536, ('смочь', 0): 0.03731343283582089, ('купить', 0): 0.03731343283582089, ('превлекательный', 0): 0.022388059701492536, ('цена', 0): 0.03731343283582089, ('самый', 0): 0.022388059701492536, ('день', 0): 0.022388059701492536, ('магазин', 0): 0.022388059701492536, ('воспользоваться', 0): 0.022388059701492536, ('большой', 0): 0.022388059701492536, ('скидка', 0): 0.05223880597014925, ('который', 0): 0.03731343283582089, ('именно', 0): 0.022388059701492536, ('пожалуйста', 0): 0.03731343283582089, ('срочно', 0): 0.022388059701492536, ('открыть', 0): 0.022388059701492536, ('прочитать', 0): 0.06716417910447761, ('это', 0): 0.03731343283582089, ('письмо', 0): 0.05223880597014925, ('конец', 0): 0.022388059701492536, ('50', 0): 0.022388059701492536, ('хотеть', 0): 0.03731343283582089, ('получить', 0): 0.03731343283582089, ('наличный', 0): 0.022388059701492536, ('деньга', 0): 0.022388059701492536, ('бесплатно', 0): 0.022388059701492536, ('рассказать', 0): 0.022388059701492536, ('дополнительный', 0): 0.022388059701492536, ('доход', 0): 0.022388059701492536, ('благодаря', 0): 0.022388059701492536, ('бизнес', 0): 0.022388059701492536, ('дом', 0): 0.022388059701492536, ('проверить', 0): 0.022388059701492536, ('свой', 0): 0.05223880597014925, ('vip', 0): 0.022388059701492536, ('статус', 0): 0.022388059701492536, ('помощь', 0): 0.03731343283582089, ('специальный', 0): 0.022388059701492536, ('сервис', 0): 0.022388059701492536, ('зарегистрироваться', 0): 0.022388059701492536, ('ссылка', 0): 0.022388059701492536, ('ниже', 0): 0.022388059701492536, ('добавить', 0): 0.022388059701492536, ('друг', 0): 0.022388059701492536, ('электронный', 0): 0.05223880597014925, ('книга', 0): 0.06716417910447761, ('«целевой', 0): 0.022388059701492536, ('маркетинг»', 0): 0.022388059701492536, ('23', 0): 0.022388059701492536, ('заработать', 0): 0.022388059701492536, ('50000', 0): 0.022388059701492536, ('следующий', 0): 0.03731343283582089, ('сделка', 0): 0.022388059701492536, ('провести', 0): 0.022388059701492536, ('опрос', 0): 0.022388059701492536, ('среди', 0): 0.022388059701492536, ('подписчик', 0): 0.022388059701492536, ('шаблон', 0): 0.03731343283582089, ('нравиться', 0): 0.022388059701492536, ('ответить', 0): 0.022388059701492536, ('загрузить', 0): 0.022388059701492536, ('успешный', 0): 0.03731343283582089, ('маркетолог', 0): 0.03731343283582089, ('87', 0): 0.022388059701492536, ('нынешний', 0): 0.022388059701492536, ('климат', 0): 0.022388059701492536, ('коммерции…', 0): 0.022388059701492536, ('онлайн', 0): 0.022388059701492536, ('продажах…', 0): 0.022388059701492536, ('искать', 0): 0.022388059701492536, ('информация', 0): 0.022388059701492536, ('предоставлять', 0): 0.022388059701492536, ('нужный', 0): 0.022388059701492536, ('ваш', 0): 0.06716417910447761, ('этот', 0): 0.05223880597014925, ('исчезнуть', 0): 0.022388059701492536, ('свободный', 0): 0.022388059701492536, ('доступ', 0): 0.022388059701492536, ('четверг', 0): 0.022388059701492536, ('заставить', 0): 0.022388059701492536, ('маркетинг', 0): 0.03731343283582089, ('работать', 0): 0.022388059701492536, ('автопилот', 0): 0.022388059701492536, ('эксклюзивный', 0): 0.022388059701492536, ('интервью', 0): 0.022388059701492536, ('марк', 0): 0.022388059701492536, ('кьюбан', 0): 0.022388059701492536, ('доступно', 0): 0.022388059701492536, ('инвестиционный', 0): 0.022388059701492536, ('хитрость', 0): 0.022388059701492536, ('принести', 0): 0.02238805970149253 ...

# %% [markdown]
# Предобрабатываем тестовое предложение и запускаем классификатор для него:

# %%
test1 = ['На следующей неделе консультация со студ. активом?']

print(preprocess(test1)[0])
classify(classr, preprocess(test1)[0])
# Out:
# ['следующий', 'неделя', 'консультация', 'студа', 'актив']
# 1

# %%
test2 = ['Сегодня распродажа, скидки 50% на все, только VIP пользователям!']

print(preprocess(test2)[0])
classify(classr, preprocess(test2)[0])
# Out:
# ['сегодня', 'распродажа', 'скидка', '50', 'vip', 'пользователь']
# 0

# %%
test3 = ['Зарегистрируйся по ссылке ниже и добавь меня в друзья.']

print(preprocess(test3)[0])
classify(classr, preprocess(test3)[0])
# Out:
# ['зарегистрироваться', 'ссылка', 'ниже', 'добавить', 'друг']
# 0
